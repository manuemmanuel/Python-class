# %% [markdown]
# <a href="https://colab.research.google.com/github/manuemmanuel/Python-class/blob/main/module_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Module -3 (Graphics) (7 hours)**
#
#
# Graphics  –  Terminal-based programs, Simple Graphics using Turtle, Operations, 2D Shapes, Colors and RGB Systems, A case study. Image Processing – Basic image processing with inbuilt
# functions.
#
# Graphical User Interfaces –  Event-driven programming, Coding simple GUI-based
# programs : Windows, Labels, Displaying images, Input text entry, Popup dialog boxes, Command buttons, A case study.

# %% [markdown]
# # Basic Concepts in Image Processing
#
#
# 1. **Analog vs. Digital Information**
#
# Analog information is continuous (e.g., time on an analog clock, sound waves on a vinyl record, or light intensity in a photograph).
#
# Digital information consists of discrete values (e.g., numbers on a digital clock, text characters, or digital images).
#
# Converting an analog image into a digital format requires breaking continuous information into discrete units.
#
# **2.Sampling and Digitization of Images**
#
# A visual scene contains infinite color and intensity values.
#
# To digitize an image, discrete points (pixels) are sampled on a two-dimensional grid.
#
# Higher sampling rates (more pixels) improve image quality but have practical limits based on human perception.
#
# **3. Pixel Density and Image Quality**
#
# The human eye cannot distinguish objects closer than 0.1 mm apart.
#
# A sufficient sampling rate is 10 pixels per millimeter or 250 pixels per inch (PPI).
#
# A 3x5 inch image at 250 PPI requires 937,500 pixels (~1 megapixel) for high accuracy.
#
# Lower resolutions can still provide acceptable image quality for most purposes.

# %% [markdown]
# https://pixspy.com/

# %% [markdown]
# # Image File Formats and Compression
#
# **1. Raw Image Files**
#
# Stores all sampled data, preserving the highest quality.
#
# Large file size due to uncompressed data.
#
# Useful for professional photography but inefficient for storage and sharing.
#
# **2. Compressed Image Formats**
#
# Developed to reduce file size for storage and faster network transmission.
# Two widely used formats: JPEG and GIF.
#
# **3. JPEG (Joint Photographic Experts Group)**
#
# Uses lossless and lossy compression techniques.
#
# *Lossless compression*: Stores position data instead of duplicate colors, preserving image quality.
#
# *Lossy compression:* Approximates larger regions of colors, reducing file size while maintaining visual quality.
#
# Suitable for photographs and detailed images.
#
# **4. GIF (Graphics Interchange Format)**
#
# Uses a color palette-based compression (max 256 colors).
#
# Replaces color values with integer keys from a limited palette.
#
# Efficient for flat-color images like cartoons, icons, and banners.
#
# Lossy compression but optimized for specific image types.

# %% [markdown]
# # Properties of Images
#
# **Image Representation in Programs**
#
#
# When an image is loaded, software maps its bits into a rectangular grid of colored pixels.
#
# The grid’s coordinates range from (0,0) in the upper-left to (width – 1, height – 1) in the lower-right.
#
# This differs from the Cartesian coordinate system, where (0,0) is typically the center.
#
# **Image Dimensions**
#
# Defined by width (number of pixels horizontally) and height (number of pixels vertically).
#
# Each pixel has a specific position (x, y) in the grid.
#
# **Color Representation: RGB Model**
#
# Each pixel’s color is defined by an (r, g, b) tuple, where:
#
#     r = Red component (0-255)
#
#     g = Green component (0-255)
#
#     b = Blue component (0-255)
#
# Combining these values produces millions of possible colors.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Coordinate System (x, y)**
#
# The top-left pixel is at (0,0) and the bottom-right pixel is at (width-1, height-1).
#
# The x-axis moves rightward, and the y-axis moves downward, just as described in the SCSS.
#
# **2. RGB Color Representation**
#
# Each pixel is identified by its (x, y) coordinates and has a corresponding (r, g, b) color value.
#
#     Example from the image:
#
#     (1,1) → (255,255,0) (Yellow)
#
#     (5,2) → (51,51,255) (Blue)
#
#     (0,5) → (57,181,74) (Greenish)
#
# **3. Image Manipulation Relevance**
#
# The color and position of each pixel can be modified using image-processing techniques like color filtering, brightness adjustment, and edge detection.
#
# Software like Photoshop, OpenCV, and PIL use this grid-based approach to process images.

# %% [markdown]
# **PIL (Python Imaging Library)**
#
# PIL (now maintained as Pillow) is used for opening, manipulating, and saving images in Python.
#
# ✅ Key Features:
#
# Supports multiple image formats (JPEG, PNG, BMP, etc.).
#
# Allows drawing, cropping, resizing, rotating, and filtering images.
#
# Used with Matplotlib for visualization.

# %%
# !pip install pillow

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Open the image
img = Image.open("/content/drive/MyDrive/Photo/cars.jpg")

# Display the image using Matplotlib
plt.imshow(img)
plt.axis("on")  # Hide axes
plt.show()

# %% [markdown]
# **Alternative using IPython**

# %%
from PIL import Image
from IPython.display import display

# Open the image
img = Image.open("/content/drive/MyDrive/Photo/cars.jpg")

# Display the image in Colab
display(img)

# %%
from PIL import Image

# Load an image
i = Image.open("/content/drive/MyDrive/Photo/cars.jpg")

# Get width and height
print(i.width, i.height)

# Get pixel value at (x, y)
pixel = i.getpixel((10, 10))
print(pixel)  # (R, G, B) values

# Set pixel (modifies the image in RGB mode)
i.putpixel((100, 100), (250,250, 250))  # Set to white

# Clone (copy) an image
i_clone = i.copy()

# Save the modified image
i.save("cars2.gif")
# Out:
# 3840 1080
# (5, 5, 17)

# %% [markdown]
# *3840* × 1080 refers to the resolution of an image or display screen.
#
#
# Breaking it Down:
#
#     3840 pixels (width) → The number of pixels horizontally.
#
#     1080 pixels (height) → The number of pixels vertically.
#
#     Aspect Ratio: 32:9 (Ultra-Wide)
#
# * Common Usage: Dual 1080p screens, ultra-wide monitors, gaming, video editing

# %% [markdown]
# **Matplotlib – Image Display & Visualization**
#
# Matplotlib is primarily used for data visualization, but it also supports image display.
#
#     ✅ Why Use Matplotlib for Images?
#
# 1. Works inside Jupyter Notebook & Google Colab.
#
# 2. Can display multiple images in a single figure.
#
# 3. Supports color maps, overlays, and annotations.

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# Open the image
img = Image.open("/content/drive/MyDrive/Photo/cars.jpg")

# Convert image to NumPy array for better pixel access
img_array = np.array(img)

# Display the image with detailed axis labels
plt.figure(figsize=(10, 6))  # Adjust figure size
plt.imshow(img)

# Set axis labels
plt.xlabel("Width (pixels)")
plt.ylabel("Height (pixels)")

# Show pixel grid for easy reference
plt.xticks(np.linspace(0, img.width, num=10, dtype=int))  # 10 evenly spaced width labels
plt.yticks(np.linspace(0, img.height, num=10, dtype=int))  # 10 evenly spaced height labels
plt.grid(visible=True, color="red", linestyle="--", linewidth=0.5)  # Light grid lines for reference

plt.show()

# %%
# Set pixel (modifies the image in RGB mode) with Visible Changes

from PIL import Image

# Load the image
i = Image.open("/content/drive/MyDrive/Photo/cars.jpg")

# Get width and height
print("Width:", i.width, "Height:", i.height)

# Modify a large block of pixels for visibility
for x in range(500, 800):  # Wider range in X-direction
    for y in range(300, 600):  # Taller range in Y-direction
        i.putpixel((x, y), (0, 255, 0))  # Set to bright green for visibility

# Save the modified image
i.save("cars_modified.jpg")

# Show the modified image
i.show()
# Out:
# Width: 3840 Height: 1080

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

# Create an image
img = Image.new("RGB", (400, 300), "white")
draw = ImageDraw.Draw(img)

# Draw a horizontal line
draw.line([50, 150, 350, 150], "red", 5)  # (x1, y1, x2, y2)

# Display the image using Matplotlib
plt.imshow(img)
plt.axis("on")  # Hide axes
plt.show()

# %% [markdown]
# **Basic Image Processing with OpenCV (Inbuilt Functions)**
#
# OpenCV provides many inbuilt functions for basic image processing, such as:
#
# ✔ Reading and displaying images
#
# ✔ Converting images to grayscale
#
# ✔ Resizing images
#
# ✔ Rotating images
#
# ✔ Flipping images
#
# ✔ Applying filters (blurring, edge detection, etc.)

# %%
import cv2
from google.colab.patches import cv2_imshow # Import the cv2_imshow function

# Load image
image = cv2.imread("/content/drive/MyDrive/Photo/cars.jpg")

# Display image using cv2_imshow
cv2_imshow(image) # Replace cv2.imshow with cv2_imshow
cv2.waitKey(1)  # Wait for a key press
cv2.destroyAllWindows()  # Close the window
# Out:
# <PIL.Image.Image image mode=RGB size=3840x1080>

# %%
from google.colab.patches import cv2_imshow

# %%
# !pip install opencv-python

# %%
# to know the open cv version
import cv2
print("OpenCV Version:", cv2.__version__)
# Out:
# OpenCV Version: 4.11.0

# %%
#files to upload files (local machine)

from google.colab import files
import cv2
from google.colab.patches import cv2_imshow

# Upload file
uploaded = files.upload()


image_path = list(uploaded)[0]
#✔ uploaded is a dictionary where keys are filenames.
#✔ list(uploaded) converts only the keys to a list.
#✔ [0] accesses the first filename directly.

# Load the image
image = cv2.imread(image_path)

# Check if the image is loaded correctly
if image is None:
    print("Error: Unable to load the image. Check the file path.")
else:
    # Display the image
    cv2_imshow(image)
# Out:
#      <input type="file" id="files-46c8178f-27e7-438d-a4c1-1c3afda6279c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46c8178f-27e7-438d-a4c1-1c3afda6279c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Convert to grayscale
import cv2
from google.colab.patches import cv2_imshow

# Load the image
image = cv2.imread("/content/drive/MyDrive/Photo/cars.jpg")

# Convert to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display grayscale image
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=3840x1080>

# %%
# RESIZE IMAGE
import cv2
from google.colab.patches import cv2_imshow

# Load the image
image = cv2.imread("/content/drive/MyDrive/Photo/fairy-garden-6.jpg")

# Resize image
resized_image = cv2.resize(image, (200, 150))  # Resize to 200x150 pixels


# Display resized image
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x150>

# %%
# Flip the image
import cv2
from google.colab.patches import cv2_imshow

# Load the image
image = cv2.imread("/content/drive/MyDrive/Photo/cars.jpg")

# Flip the image horizontally
flipped_image = cv2.flip(image,0)

# Display flipped image
cv2_imshow(flipped_image)

# %%
import cv2
from google.colab.patches import cv2_imshow
# Load the image
image = cv2.imread("/content/sample_data/house.png")
# Add text
cv2.putText(image, "My home sweet home...", (750, 650), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
# Display image with text
cv2_imshow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-61709c426277> in <cell line: 0>()
#       6 cv2.putText(image, "My home sweet home...", (750, 650), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
#       7 # Display image with text
# ----> 8 cv2_imshow(image)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %% [markdown]
# **Parameter-wise Explanation**
#
# image → The image where text will be drawn.
#
# "My home sweet home..." → The text string to be displayed.
#
# (750, 700) → Coordinates (x, y) of the bottom-left corner of the text in pixels.
#
# x = 750 (Right shift along width)
#
# y = 700 (Move down along height)
#
# cv2.FONT_HERSHEY_SIMPLEX → The font type.
#
# Other fonts: cv2.FONT_HERSHEY_PLAIN, cv2.FONT_HERSHEY_COMPLEX, etc.
#
# 1 → Font scale (size).
#
# Increase to make text larger (e.g., 2 or 3).
#
# (255, 0, 0) → Text color in BGR format.
#
# (255, 0, 0) = Blue
#
# (0, 255, 0) = Green
#
# (0, 0, 255) = Red
#
# 2 → Thickness of the text (in pixels).

# %% [markdown]
# **What is Edge Detection?**
#
# Edge detection is a technique used in image processing and computer vision to identify boundaries between objects in an image. It highlights sudden intensity changes (contrast) in an image, which usually indicate object edges.
#
# Why is Edge Detection Important?
#
# ✔ Helps in object detection & recognition
#
# ✔ Used in medical imaging (X-rays, MRIs, etc.)
#
# ✔ Used in autonomous driving (lane detection, obstacle detection)
#
# ✔ Key step in image segmentation & feature extraction

# %%
# Load the image
image = cv2.imread("/content/drive/MyDrive/Photo/cars.jpg")

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Canny Edge Detection (threshold1 = 100, threshold2 = 200)
#100 and 200 are the two threshold values:
#threshold1 (100): Lower threshold – pixels with gradient magnitude below this are rejected.
#threshold2 (200): Upper threshold – pixels with a gradient magnitude above this are accepted as edges.
edges = cv2.Canny(gray, 100, 200)

# Display result
import matplotlib.pyplot as plt # Import the matplotlib library
plt.imshow(edges, cmap='gray')
plt.title("Canny Edge Detection")
plt.axis("off")
plt.show()

# %% [markdown]
# # **Graphical User Interfaces (GUI)**
#
# Python provides several libraries for creating Graphical User Interfaces (GUI).
#
# Graphical User Interfaces (GUI) allow users to interact with software using graphical elements like windows, buttons, labels, text boxes, and images, instead of a command-line interface (CLI).
#
# The most commonly used ones are:
#
#     1. Tkinter (Built-in, lightweight)
#
#     2. PyQt (Advanced, based on Qt framework)
#
#     3. Kivy (For multi-touch applications)
#
#     4. PySide (Similar to PyQt)
#
#     5. wxPython (Native look on different OS)

# %% [markdown]
# **1️⃣ Tkinter (Built-in GUI Library)**
#
# Tkinter is the default GUI toolkit for Python and comes pre-installed.
#
#     Tkinter does not work in Google Colab because it requires a GUI environment, which Colab does not provide.
#
#     Colab runs in a web-based Jupyter Notebook, and Tkinter requires a local desktop environment to create windows.

# %% [markdown]
# **Install Tkinter (Linux)**
#
#     sudo apt update
#     sudo apt install python3-tk
#
# Run a Tkinter Window Locally
#
#     Save this as app.py and run it with python app.py

# %% [markdown]
# **#Tkinter program that only creates a blank window:**
#
#     # Import Tkinter
#     import tkinter as tk
#
#     # Create the main window
#     root = tk.Tk()
#
#     # Run the Tkinter event loop (displays the window)
#     root.mainloop()

# %% [markdown]
#     import tkinter as tk  # Import the Tkinter module
#
#     # Create the main application window
#     root = tk.Tk()
#
#     # Set the title of the window (root window)
#     root.title("Tkinter Example")
#
#     # Set the size of the window (width x height)
#     root.geometry("300x200")
#
#     # Create a label widget with text
#     label = tk.Label(root, text="Hello, Tkinter!")
#
#     # Add the label to the window
#     label.pack()
#
#     # Run the Tkinter event loop (keeps the window open)
#     root.mainloop()

# %% [markdown]
# **Tkinter Widget**
#
# There are a number of tkinter widgets which we can put in our tkinter application.
#
# Some of the major widgets are explained below:
#
# https://www.geeksforgeeks.org/python-gui-tkinter/

# %% [markdown]
# **Custom Window Example with Tkinter**
#
#     import tkinter as tk
#
#     # Create the root window
#     root = tk.Tk()
#
#     # Customize window properties
#     root.title("Custom Tkinter Window")  # Set window title
#     root.geometry("600x400")  # Set window size (Width x Height)
#     root.config(bg="lightblue")  # Set background color
#
#     # Create a label widget
#     label = tk.Label(root, text="Welcome to the Custom Window!", font=("Arial", 14), bg="lightblue")
#     label.pack(pady=20)  # Add padding around the label
#
#     # Create a button widget
#     button = tk.Button(root, text="Click Me", font=("Arial", 12), bg="orange", command=lambda: label.config(text="Button Clicked!"))
#     button.pack(pady=20)  # Add padding around the button
#
#     # Run the Tkinter event loop
#     root.mainloop()

# %% [markdown]
# # **Key Concepts of Event-Driven Programming**
#
# Event-driven programming is a programming paradigm in which the flow of the program is determined by events such as user actions (mouse clicks, keyboard input), sensor outputs, or messages from other programs. It is widely used in graphical user interfaces (GUIs), real-time systems, and applications that require a high level of interactivity.
#
# Key Concepts of Event-Driven Programming
#
#
# **1. Event Loop:**
#
# The event loop runs continuously, waiting for events to occur. When an event happens, it is detected and processed. For instance, in a GUI application, the event loop listens for user actions like button clicks or keyboard input.
#
# **2. Events:**
#
# Events are actions or occurrences that happen during the program's execution. Examples include mouse clicks, key presses, and messages from other programs or sensors.
#
# **3. Event Handlers (or Callback Functions):**
#
# These are functions or methods that are executed in response to specific events. When an event occurs, the event loop calls the corresponding event handler to process the event.
#
# **4. Widgets:**
#
# Widgets are elements of the user interface such as windows, buttons, labels, and text input fields. They generate events when the user interacts with them.
#
# **5. Event Binding:**
#
# Event binding connects events to event handlers. In a GUI framework like Tkinter, you can bind events to callback functions using parameters like command in a Button widget.
#
#
#
# **Example in Tkinter**
#
#
# In the Tkinter application we created earlier, event-driven programming is demonstrated as follows:
#
#
# 1. Event Loop:
#
#           The root.mainloop() call starts the event loop, making the application responsive to user actions.
#
# 2. Events:
#
#           Events include clicking the "Submit" or "Show Logs" buttons.
#
#
# 3. Event Handlers (Callback Functions):
#
#           submit_data() and show_logs() are callback functions that handle the
#
#           events of clicking the "Submit" and "Show Logs" buttons, respectively.
#
# 4. Widgets:
#
#           The application uses widgets like Button, Label, and Entry.
#
# 5. Event Binding:
#
#           The buttons are bound to their respective event handlers using the command parameter:
#
#           submit_button = tk.Button(root, text="Submit", command=submit_data)
#           logs_button = tk.Button(root, text="Show Logs", command=show_logs)

# %% [markdown]
# **Python program using Tkinter that demonstrates the following elements:**
#
# 1. **Windows**: Creating a window with a title.
#
# 2. **Labels:** Adding text labels to the window.
#
# 3. **Displaying Images:** Using PhotoImage to display an image.
#
# 4. **Input Text Entry:** Adding a text entry widget for user input.
#
# 5. **Popup Dialogue Boxes:**Displaying popup messages using messagebox.
#
# 6. **Command Buttons:** Buttons that trigger actions.
#
#
# link : https://drive.google.com/drive/folders/1Pids8RM--cgPcVXj4sR0VIVolAcXbvn8?usp=sharing

# %% [markdown]
# **Tutorial - 8: Simple Tkinter Form**
#
# Objective: Create a form that collects the user's name and age, and displays a greeting message with their name and age when they click a button.
#
# Instructions:
#
# 1. Create a window using Tkinter.
#
# 2. Add two input fields to collect the user's name and age.
#
# 3. Add a button that, when clicked, displays a personalized greeting message on the screen.
#
# 4. The greeting message should say something like: "Hello, [Name]! You are [Age] years old."

# %% [markdown]
# **Assignment Question:**
#
# Create a Tkinter-based Work Log Application with the following features:
#
# 1. A main window with the title "Work Log Application".
#
# 2. A text label at the top that says "Welcome to the Work Log Application".
#
# 3. Two text entry fields: one for the user's name and one for the number of hours worked.
#
# 4. A button labeled "Submit" that, when clicked, saves the entered name and hours worked, and displays a confirmation popup message.
#
# 5. An image displayed in the window. Ensure the image file is in a supported format (PNG, GIF, PPM, PGM).
#
# 6. Another button labeled "Show Logs" that displays a summary of all the submitted work logs in a popup message.

# %% [markdown]
# # **ipywidgets**
#
#
#
# which are interactive widgets for Jupyter Notebook and Google Colab. ipywidgets allow you to create interactive GUI components like buttons, sliders, text fields, and more inside Jupyter Notebook.
#
# Installing ipywidgets
# If you haven't installed ipywidgets, you can install it using:
#
#     pip install ipywidgets

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import ipywidgets as widgets
from IPython.display import display, clear_output

# Function to open and display a single image
def open_image(change):
    uploaded_file = change['new']
    clear_output(wait=True)  # Clear previous outputs

    # Display widgets again
    display(upload_button, message_button)

    if uploaded_file:
        # Get the first (single) file
        file_name = list(uploaded_file.keys())[0]

        # Save uploaded file locally
        with open(file_name, "wb") as f:
            f.write(uploaded_file[file_name]["content"])  # Write file content to disk

        print(f"📂 Opened: {file_name}")
        image = Image.open(file_name)

        # Display the image
        plt.figure(figsize=(4, 4))
        plt.imshow(image)
        plt.axis("off")
        plt.show()

# Function to show a popup message
def show_message(_):
    print("📢 Hello! This is a popup message.")

# Upload Button (Allows only one file)
upload_button = widgets.FileUpload(accept="image/*", multiple=False)  # Single file upload
upload_button.observe(open_image, names='value')

# Message Button
message_button = widgets.Button(description="Show Message")
message_button.on_click(show_message)

# Display Widgets in a vertical box
display(widgets.VBox([upload_button, message_button]))
# Out:
# FileUpload(value={'camping-7856198_1280.jpg': {'metadata': {'name': 'camping-7856198_1280.jpg', 'type': 'image…
# Button(description='Show Message', style=ButtonStyle())
# 📂 Opened: camping-7856198_1280.jpg
# 📢 Hello! This is a popup message.

# %%
import ipywidgets as widgets
from IPython.display import display

# Function to show "Hello, World!" when button is clicked
def say_hello(_):
    print("👋 Hello, World!")

# Create a button
hello_button = widgets.Button(description="Click Me")

# Bind function to button click event
hello_button.on_click(say_hello)

# Display the button
display(hello_button)
# Out:
# Button(description='Click Me', style=ButtonStyle())
# 👋 Hello, World!

# %%
import ipywidgets as widgets
from IPython.display import display

# Function to display the user's message
def show_message(_):
    output.clear_output()
    with output:
        print(f"📢 Your Message: {text_input.value}")

# Create input text box
text_input = widgets.Text(placeholder="Type your message here...")

# Create submit button
submit_button = widgets.Button(description="Show Message")
submit_button.on_click(show_message)

# Create output area
output = widgets.Output()

# Display widgets
display(text_input, submit_button, output)
# Out:
# Text(value='', placeholder='Type your message here...')
# Button(description='Show Message', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display

# Function to display the user's message in a new widget box
def show_message(_):
    message_box = widgets.Output()
    with message_box:
        print(f"📢 Your Message: {text_input.value}")
    display(message_box)

# Create input text box
text_input = widgets.Text(placeholder="Type your message here...")

# Create submit button
submit_button = widgets.Button(description="Show Message")
submit_button.on_click(show_message)

# Display widgets
display(text_input, submit_button)
# Out:
# Text(value='', placeholder='Type your message here...')
# Button(description='Show Message', style=ButtonStyle())
# Output()
